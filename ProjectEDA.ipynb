# %% [markdown]
# # EDA (Exploratory Data Analysis) assessment:  Indian Startup Funding

# %%
# import the libraries...
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
#Check the current working directories..
pwd

# %%
#Read the data set of "Startup Funding" from variable name data
df=pd.read_csv('C:\\Users\\LENOVO\\Python\\Project_EDA\\startup_funding.csv')

# %%
#printing the data..
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
#To find out the shape of data
df.shape
# Out:
# (3044, 10)

# %%
#Print head of dataframe
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
#Print tail of dataframe
df.tail()
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039            NaN        Asia Pacific Internet Group  Private Equity
# 3040            NaN                     KARSEMVEN Fund  Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                         MakeMyTrip  Private Equity
# 3043            NaN  UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# ...

# %%
#To show the information of all the important aspects of dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
#To find out duplicate values 
df[df.duplicated()].shape
# Out:
# (0, 10)

# %%
#To count the duplicated values 
df.duplicated().value_counts()
# Out:
# False    3044
# Name: count, dtype: int64

# %%
#Drop duplicate values 
df= df.drop_duplicates()
df.shape
# Out:
# (3044, 10)

# %%
#To find the size of the data
df.size
# Out:
# 30440

# %%
#Shape of unique values of data set (after removing duplicate values)
df.shape
# Out:
# (3044, 10)

# %%
#To find null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Remarks              2625
# Amount in USD         960
# SubVertical           936
# City  Location        180
# Industry Vertical     171
# Investors Name         24
# InvestmentnType         4
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# dtype: int64

# %%
#Removing null values
df=df.drop(['Remarks'],axis=1)
df["Amount in USD"].fillna(0, inplace = True)

# %%
df = df.dropna(axis = 0)

# %%
#Detecting null values 
df.isnull().sum()
# Out:
# Sr No                0
# Date dd/mm/yyyy      0
# Startup Name         0
# Industry Vertical    0
# SubVertical          0
# City  Location       0
# Investors Name       0
# InvestmentnType      0
# Amount in USD        0
# dtype: int64

# %%
#Dateset after removing null values
df.shape
# Out:
# (2080, 9)

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 2103   2104      29/01/2016                    Rare Media
# 2104   2105      29/01/2016                        TinMen
# 2105   2106      29/01/2016                    CodingLabs
# 2106   2107      30/01/2016                   FindUrClass
# 2107   2108      30/01/2016                    DesignBids
#
#         Industry Vertical                             SubVertical  \
# 0                  E-Tech                              E-learning
# 1          Transportation               App based shuttle service
# 2              E-commerce   Retailer of baby and toddler products
# ...

# %%
#Describe summary of the dataset
df.describe(include="all")
# Out:
#               Sr No Date dd/mm/yyyy Startup Name  Industry Vertical  \
# count   2080.000000            2080         2080               2080
# unique          NaN             755         1772                101
# top             NaN      30/11/2016       Meesho  Consumer Internet
# freq            NaN              11            6                928
# mean    1060.858654             NaN          NaN                NaN
# std      605.712410             NaN          NaN                NaN
# min        1.000000             NaN          NaN                NaN
# 25%      540.750000             NaN          NaN                NaN
# 50%     1062.500000             NaN          NaN                NaN
# 75%     1583.250000             NaN          NaN                NaN
# max     2108.000000             NaN          NaN                NaN
#
#                     SubVertical City  Location         Investors Name  \
# count                      2080           2080                   2080
# ...

# %%
import pandas as pd


# Rename columns
df = df.rename(columns={'Date dd/mm/yyyy': 'Date'})

print(df)
# Out:
#       Sr No        Date                  Startup Name    Industry Vertical  \
# 0         1  09/01/2020                        BYJU’S               E-Tech
# 1         2  13/01/2020                        Shuttl       Transportation
# 2         3  09/01/2020                     Mamaearth           E-commerce
# 3         4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4         5  02/01/2020                        Fashor  Fashion and Apparel
# ...     ...         ...                           ...                  ...
# 3039   3040  29/01/2015                    Printvenue                  NaN
# 3040   3041  29/01/2015                      Graphene                  NaN
# 3041   3042  30/01/2015                Mad Street Den                  NaN
# 3042   3043  30/01/2015                     Simplotel                  NaN
# 3043   3044  31/01/2015              couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# ...

# %% [markdown]
# # 1 :- Investment type in Indian startup Funding company.

# %%
plt.figure(figsize=(12,6))
df['InvestmentnType'].value_counts().head(15).plot(kind='bar')
plt.title('Investment Type')
plt.show()

# %% [markdown]
# ## Report - 1 :
# <span style="color:green"> Private equity and seed funding are two most commonly used Investment type.</span>

# %% [markdown]
# # 2 :- Top 10 startup name company Name.

# %%
plt.figure(figsize=(12,6))
df['Startup Name'].value_counts().head(15).plot(kind='bar')
plt.title('Top 10 Startup Name')
plt.show()

# %% [markdown]
# ## Report -2 :
# <span style="color:green">The above graph shows the top 10 Startup Company name.</span>

# %% [markdown]
# # 3 :- Top 10 Investers Name.

# %%
df['Investors Name'].value_counts().head(10).plot(kind='bar',figsize=(12,6),title='Top 10 investors Name')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Report - 3 :
# <span style="color:green">The above are the top 10 Investers Name.</span>

# %% [markdown]
# # 4 :- How the Investment Type distributed.

# %%
sns.histplot(df['InvestmentnType'],bins=5,kde=True)
plt.title("Investment Type")
plt.xticks(rotation=90)
plt.show()

df['InvestmentnType'].value_counts().head(10).plot(kind='bar',figsize=(12,6),title='Investment Type')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Report - 4 :
# <span style="color:green">The above chart shows how investment type are distributed with the count values.

# %% [markdown]
# # 5 :- which location recieved higest startup.

# %%
cityCount = df['City  Location'].value_counts()[:10]
print(cityCount)
# Out:
# City  Location
# Bangalore    700
# Mumbai       567
# New Delhi    421
# Gurgaon      287
# Bengaluru    141
# Pune         105
# Hyderabad     99
# Chennai       97
# Noida         92
# Gurugram      50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=cityCount.index,y=cityCount.values, alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Location', fontsize=12)
plt.ylabel('Number of Startups', fontsize=12)
plt.title("Location of Startups", fontsize=16)
plt.show()

# %% [markdown]
# ## Report - 5 :
# <span style="color:green">We can see here that Banglore is hot favourite for startups
#  Difference between Banglore and Mumbai is having huge number of difference compare to difference between other cities.</span>

# %% [markdown]
# # 6 :- Investors Distribution

# %%
investorCounts = df['Investors Name'].value_counts()[:10]
print(investorCounts)
# Out:
# Investors Name
# Undisclosed Investors       39
# Undisclosed investors       30
# Ratan Tata                  25
# Indian Angel Network        23
# Kalaari Capital             16
# Group of Angel Investors    15
# Sequoia Capital             15
# Undisclosed Investor        12
# Accel Partners              12
# Venture Catalysts           11
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=investorCounts.index,y=investorCounts.values,alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Investors', fontsize=12)
plt.ylabel('Number of Startups', fontsize=12)
plt.title("Investors distribution", fontsize=16)
plt.show()

# %% [markdown]
# ## Report - 6 :
# <span style="color:green">We have some ambiguity here in name 'Undisclosed Investors' we need to remove this duplication from our dataset we'll process this attribute and make all 'Undisclosed Investors' as same.</span>

# %% [markdown]
# # 7 :- Industry Vertical Distribution

# %%
df['Industry Vertical'][df['Industry Vertical']=='eCommerce'] = 'ECommerce'
industryCounts = df['Industry Vertical'].value_counts()[:15]
print(industryCounts)
# Out:
# Industry Vertical
# Consumer Internet    941
# Technology           478
# ECommerce            247
# Healthcare            70
# Finance               62
# Logistics             32
# E-Commerce            29
# Education             24
# Food & Beverage       23
# Ed-Tech               14
# E-commerce            12
# FinTech                9
# IT                     8
# Ecommerce              8
# Others                 6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=industryCounts.index, y=industryCounts.values, alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Industry', fontsize=12)
plt.ylabel('Number of Startups', fontsize=12)
plt.title("Industry distribution", fontsize=16)
plt.show()

# %% [markdown]
# ## Report - 7 :
# <span style="color:green">Majority of startups are working in 'Consumer Internet'
# 2nd heighest that is 'technology' some startups interested in developing technologies </span>

# %% [markdown]
# # 8 :- Number of startup according to sub-vertical

# %%
subVerticalCounts = df['SubVertical'].value_counts()[:5]
print(subVerticalCounts)
# Out:
# SubVertical
# Online Lending Platform      11
# Online Pharmacy              10
# Food Delivery Platform        8
# Online Education Platform     5
# Education                     5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=subVerticalCounts.index,y=subVerticalCounts.values, alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Sub-vertical', fontsize=12)
plt.ylabel('Number of Startups', fontsize=12)
plt.title("Sub-Vertcial distribution", fontsize=16)
plt.show()

# %% [markdown]
# ## Report - 8 :
# <span style="color:green"> Online Pharmacy is the main concentartion followed by Food Delivery platform for new startups.</span>

# %% [markdown]
# ## Final EDA
# --> Year 2016 was most hapening time for the startups.
#
# --> Banglore the electronic city of india is hot favourite for startups followed by Mumbai and New Delhi.
#
# --> Seed Funding and Private Equity funding are the two major funding types of investment in startups.
#
# --> Large number of the startup's funding is confidential-undisclosed. But as far as we know that Sequoia capital has invested in many            startups. So New founders of startup target 'Sequoia Capital' to get investment for their startup.
#
# --> Majority of startups are working in Consumer Internet, 2nd heighest that is technology some startups interested in developing                 new technologies.
#
# --> Online Pharmacy is the main concentartion followed by Food Delivery platform for new startups.
